# %%
import xarray as xr
import pandas as pd

# %%
ds01 = xr.open_dataset("H:/github/python/seafog/data/CFdata/59754.201508-201809_lon110.25_lat20.125.sstk.nc")
ds02 = xr.open_dataset("H:/github/python/seafog/data/CFdata/59754.201508-201809_lon110.25_lat20.125.t2mm.nc")
print(ds01)
print(ds02)
# Out:
# <xarray.Dataset>
# Dimensions:  (level: 1, time: 1338)
# Coordinates:
#     lon      float32 ...
#     lat      float32 ...
#   * level    (level) float32 0.0
#   * time     (time) datetime64[ns] 2015-10-01 ... 2018-05-31T12:00:00
# Data variables: (12/57)
#     flag     (time) float32 ...
#     stat     (time) float32 ...
#     tstr     (time) float32 ...
#     ystr     (time) float32 ...
#     sstk000  (time) float32 ...
#     sstk003  (time) float32 ...
#     ...       ...
#     sstk210  (time) float32 ...
#     sstk216  (time) float32 ...
#     sstk222  (time) float32 ...
#     sstk228  (time) float32 ...
#     sstk234  (time) float32 ...
#     sstk240  (time) float32 ...
# Attributes:
#     DODS_EXTRA.Unlimited_Dimension:  time
# <xarray.Dataset>
# Dimensions:  (level: 1, time: 1276)
# Coordinates:
#     lon      float32 ...
#     lat      float32 ...
#   * level    (level) float32 0.0
#   * time     (time) datetime64[ns] 2015-08-01 ... 2018-05-31T12:00:00
# ...

# %%
time01 = ds01.time
time02 = ds02.time
print(time01)
# Out:
# <xarray.DataArray 'time' (time: 1338)>
# array(['2015-10-01T00:00:00.000000000', '2015-10-01T12:00:00.000000000',
#        '2015-10-02T00:00:00.000000000', ..., '2018-05-30T12:00:00.000000000',
#        '2018-05-31T00:00:00.000000000', '2018-05-31T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     lon      float32 ...
#     lat      float32 ...
#   * time     (time) datetime64[ns] 2015-10-01 ... 2018-05-31T12:00:00

# %%
newtime01, newtime02 =  xr.align(time01, time02)

# %%
ds01['sstk000'].sel(time=newtime01)
# Out:
# <xarray.DataArray 'sstk000' (time: 1214)>
# array([302.39233, 302.5232 , 302.5232 , ..., 302.063  , 302.063  , 302.12646],
#       dtype=float32)
# Coordinates:
#     lon      float32 ...
#     lat      float32 ...
#   * time     (time) datetime64[ns] 2015-10-01 ... 2018-05-31T12:00:00
# Attributes:
#     name:           sstk
#     valid_min:      0.0
#     standard_name:  sea_surface_skin_temperature
#     units:          K
#     long_name:      sea surface temperature
#     short_name:     SST

# %%
print(newtime02)
# Out:
# <xarray.DataArray 'time' (time: 1214)>
# array(['2015-10-01T00:00:00.000000000', '2015-10-01T12:00:00.000000000',
#        '2015-10-02T00:00:00.000000000', ..., '2018-05-30T12:00:00.000000000',
#        '2018-05-31T00:00:00.000000000', '2018-05-31T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time     (time) datetime64[ns] 2015-10-01 ... 2018-05-31T12:00:00
#     lon      float32 ...
#     lat      float32 ...

# %%
xr.align()

# %%
ds['sstk024'][255:260].plot()

# %%
ds['sstk072'][255:260].time
# Out:
# <xarray.DataArray 'time' (time: 5)>
# array(['2016-03-07T12:00:00.000000000', '2016-03-08T00:00:00.000000000',
#        '2016-03-08T12:00:00.000000000', '2016-03-09T00:00:00.000000000',
#        '2016-03-09T12:00:00.000000000'], dtype='datetime64[ns]')
# Coordinates:
#     lon      float32 ...
#     lat      float32 ...
#   * time     (time) datetime64[ns] 2016-03-07T12:00:00 ... 2016-03-09T12:00:00

# %%
ds['sstk072'][255:260].values
# Out:
# array([      nan, 285.40063, 291.594  , 291.60126, 292.0678 ],
#       dtype=float32)

# %%
ds['sstk024'].sel(time=slice('2016-12-29', '2017-9-5')).plot()

# %%
ds['sstk024'].sel(time=slice('2016-12-29', '2017-9-5')).time
# Out:
# <xarray.DataArray 'time' (time: 16)>
# array(['2016-12-29T00:00:00.000000000', '2016-12-29T12:00:00.000000000',
#        '2016-12-30T00:00:00.000000000', '2016-12-30T12:00:00.000000000',
#        '2016-12-31T00:00:00.000000000', '2016-12-31T12:00:00.000000000',
#        '2017-09-01T00:00:00.000000000', '2017-09-01T12:00:00.000000000',
#        '2017-09-02T00:00:00.000000000', '2017-09-02T12:00:00.000000000',
#        '2017-09-03T00:00:00.000000000', '2017-09-03T12:00:00.000000000',
#        '2017-09-04T00:00:00.000000000', '2017-09-04T12:00:00.000000000',
#        '2017-09-05T00:00:00.000000000', '2017-09-05T12:00:00.000000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#     lon      float32 110.2
#     lat      float32 20.12
#   * time     (time) datetime64[ns] 2016-12-29 ... 2017-09-05T12:00:00
